# %% [markdown]
# # CPU+GPU Test of `calcSpatialFreqsFilterBank`
#
# This notebook replicates in Python/NumPy the MATLAB test script `testCalcSpatialFreqsFilterBank.m` for the FilterBank local spatial-frequency estimator `calcSpatialFreqsFilterBank`. The core functions are imported from `FPA_Numpy.py` and `FPA_TensorFlow.py` .
# Here we check NumPy-CPU and TensorFlow-GPU implementations

# %%
# ---
# ✅ Colab bootstrap for LensPMD
# How to open in Colab:
# 1) Clone the LensPMD repo into Google Drive.
# 2) In Drive (web), right-click the notebook → “Open with” → “Google Colab”.
# 3) Run this cell to mount Drive, set the working directory, and verify required paths.
# ---

import os
from pathlib import Path

# === Detect Colab =============================================================
try:
    import google.colab  # type: ignore
    IN_COLAB = True
except ImportError:
    IN_COLAB = False

print(f"Running in Colab? {IN_COLAB}")

# === Setup when in Colab ======================================================
if IN_COLAB:
    from google.colab import drive  # type: ignore
    DRIVE_MOUNT_POINT = "/content/drive"
    PROJECT_REL_PATH = "MyDrive/Colab Notebooks/72_OM4M008_LENSPMD25_CPU_GPU_FPA/Python_src"
    REQUIRED_PATH = "/content/drive/MyDrive/Colab Notebooks/72_OM4M008_LENSPMD25_CPU_GPU_FPA/local_data"

    # Mount Google Drive
    drive.mount(DRIVE_MOUNT_POINT, force_remount=True)

    # Set working directory
    project_path = Path(DRIVE_MOUNT_POINT) / PROJECT_REL_PATH
    if not project_path.exists():
        raise FileNotFoundError(f"❌ Project directory not found: {project_path}")

    os.chdir(project_path)
    print("✅ Working Directory:", Path.cwd())

    # Verify required local_data folder exists
    local_data_path = Path(REQUIRED_PATH)
    if not local_data_path.exists():
        raise FileNotFoundError(
            f"❌ Required directory not found: {local_data_path}\n"
            "Please ensure 'local_data' exists in the LensPMD folder in your Drive."
        )

    print("✅ Required folder found:", local_data_path)
    print("📂 Files in Working Directory:", os.listdir())

else:
    print("Not running in Colab — skipping Drive mount and WD setup.")
    print("Current Working Directory:", Path.cwd())
# Out:
# Running in Colab? False
# Not running in Colab — skipping Drive mount and WD setup.
# Current Working Directory: c:\user\AQ_SCC\GitHub\72_OM4M008_LENSPMD25_CPU_GPU_FPA\Python_src

# %%
# ============================================================
# BOOTSTRAP: make project source importable from notebooks
#
# This cell temporarily adds the project source directory
# (parent of the "Notebooks" folder) to sys.path.
#
# Scope:
#   - Effective ONLY for the current Jupyter kernel session
#   - Does NOT modify PYTHONPATH or the Python environment
#
# Typical layout assumed:
#   Python_src/
#     ├── image_viewer_app.py
#     ├── ...
#     └── Notebooks/
#         └── this_notebook.ipynb
# ============================================================

import sys
from pathlib import Path

# Resolve notebook directory robustly
try:
    NOTEBOOK_DIR = Path(__file__).parent.resolve()
except NameError:
    # Jupyter/IPython fallback
    NOTEBOOK_DIR = Path.cwd().resolve()

PROJECT_SRC = NOTEBOOK_DIR.parent

if PROJECT_SRC.exists() and str(PROJECT_SRC) not in sys.path:
    sys.path.insert(0, str(PROJECT_SRC))
    print(f"[bootstrap] Added to sys.path: {PROJECT_SRC}")
else:
    print(f"[bootstrap] Path already present or invalid: {PROJECT_SRC}")

# %%
# para forzar que los imshow en modo debug vayan al notebook desde el que se hace la llamada 



import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

import matplotlib
# %matplotlib inline



from FPA_Numpy import calcSpatialFreqsHilbert2D_NumPy, calcSpatialFreqsFilterbank_ParVer_NumPy
from FPA_TensorFlow import calcSpatialFreqsHilbert2D_TF, calcSpatialFreqsFilterbank_ParVer_TF
from FPA_Utils import time_function, peaks_2d

from functools import partial

# check for tensor flow and list devices
print("TensorFlow version:", tf.__version__)
print("Built with CUDA:", tf.test.is_built_with_cuda())
print("GPU devices:", tf.config.list_physical_devices('GPU'))
if tf.config.list_physical_devices('GPU'):
    try:
        for d in tf.config.list_physical_devices('GPU'):
            tf.config.experimental.set_memory_growth(d, True)
    except Exception as e:
        print("Could not set memory growth:", e)

print("CPU devices:", tf.config.list_physical_devices('CPU'))
# Out:
# TensorFlow version: 2.16.2
# Built with CUDA: False
# GPU devices: []
# CPU devices: [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %%
# Synthetic interferogram (Caso 1: HIFREQ)
NR, NC = 558, 553
y, x = np.meshgrid(
    np.arange(NR, dtype=np.float32),
    np.arange(NC, dtype=np.float32),
    indexing="ij",
)
x = x - 0.5 * NC
y = y - 0.5 * NR

# ROI mask
M = np.ones((NR, NC), dtype=bool)

# Spatial carrier
w0 = np.array([np.pi/4, np.pi/4], dtype=np.float32)  # rad/px
fringe_carrier_or = np.arctan2(w0[1], w0[0])

# Smooth phase term via peaks (already sized NR x NC)
phi_0 = 3.0 * peaks_2d(NR, NC)
phi = phi_0 + w0[0] * x + w0[1] * y

# Ground-truth spatial freqs
phi_y, phi_x = np.gradient(phi.astype(np.float32))  # np.gradient -> (d/dy, d/dx)
w_phi = np.abs(phi_x + 1j * phi_y)
w_phi = w_phi * M  # apply mask
theta_or = np.arctan2(-phi_y, phi_x)

# DC and modulation in gray values
b = np.float32(100.0)
m = np.float32(64.0)
nL_mod = np.float32(0.0)
nL = 100.0 * nL_mod / m  # not used explicitly

# Interferogram in [0, 255]
g_float = b + m * np.cos(phi) + nL_mod * np.random.randn(NR, NC).astype(np.float32)
g_uint8 = np.clip(np.round(g_float), 0, 255).astype(np.uint8)
g = g_uint8.astype(np.float32)
g = g * M.astype(np.float32)

# Ground-truth phasor (for reference)
z = b * np.exp(1j * phi)
print("Synthetic interferogram generated.")
# Out:
# Synthetic interferogram generated.

# %%
# Time numpy paralell filter bank method (outputs kept if needed)
# use partial to keep funcion metadata
f_calcSpatialFreqsFilterbank_ParVer_NumPy = partial(calcSpatialFreqsFilterbank_ParVer_NumPy, g, M)

# Time  numpy paralell filter bank method and keep outputs for plotting
res_calcSpatialFreqsFilterbank_ParVer_NumPy = time_function(f_calcSpatialFreqsFilterbank_ParVer_NumPy.func.__name__, f_calcSpatialFreqsFilterbank_ParVer_NumPy, n_runs=1, verbose=True)

# calculate spatial freqs
(pred_w_phi, pred_theta_or, pred_phi_x, pred_phi_y, M_proc)=f_calcSpatialFreqsFilterbank_ParVer_NumPy()

# Error map (only meaningful where M is True)
error_map_w_phi = pred_w_phi - w_phi
mask = M

# Display w_phi estimate
plt.figure(figsize=(6, 5))
plt.imshow(pred_w_phi * M_proc, origin='upper')
plt.colorbar(label=r'$w_\phi$ (rad/px)')
plt.title(r'Estimated $w_\phi$ (rad/px)')
plt.tight_layout()
plt.show()

# Histogram of error in w_phi (rad/px)
histEdge2 = np.linspace(-np.pi/10, np.pi/10, 100)
plt.figure(figsize=(6, 4))
plt.hist(error_map_w_phi[mask].ravel(), bins=histEdge2)
plt.title('Histogram of error in $w_\phi$')
plt.xlabel(r'$w_\phi$ error (rad/px)')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# RMSE criterion
rmse_w_phi = np.sqrt(np.mean(error_map_w_phi[mask] ** 2))
print(f"RMSE(w_phi) = {rmse_w_phi:.4f} rad/px")
assert rmse_w_phi < 0.4, "RMSE condition failed (rmse_w_phi >= 0.4 rad/px)"
print("Assertion passed: RMSE(w_phi) < 0.4 rad/px")
# Out:
# [calcSpatialFreqsFilterbank_ParVer_NumPy] Warm-up time: 8526.17 ms
# [calcSpatialFreqsFilterbank_ParVer_NumPy] Run 1/1: 8305.64 ms
# calcSpatialFreqsFilterbank_ParVer_NumPy: 1 runs -> mean = 8305.64 ms, std = 0.00 ms
# RMSE(w_phi) = 0.0082 rad/px
# Assertion passed: RMSE(w_phi) < 0.4 rad/px

# %%
#this is to avoid restrting the kernel while iterating
import importlib
import FPA_TensorFlow

importlib.reload(FPA_TensorFlow)
from FPA_TensorFlow import calcSpatialFreqsFilterbank_ParVer_TF


# Time tensor flow paralell filter bank method (outputs kept if needed)
# use partial to keep funcion metadata
f_calcSpatialFreqsFilterbank_ParVer_TF = partial(calcSpatialFreqsFilterbank_ParVer_TF, g, M, calcMethod = "maxFreq")

# Time tensor flow paralell filter bank method and keep outputs for plotting
res_calcSpatialFreqsFilterbank_ParVer_TF = time_function(f_calcSpatialFreqsFilterbank_ParVer_TF.func.__name__, f_calcSpatialFreqsFilterbank_ParVer_TF, n_runs=1, verbose=True)

# calculate spatial freqs
(pred_w_phi, pred_theta_or, pred_phi_x, pred_phi_y, M_proc)=f_calcSpatialFreqsFilterbank_ParVer_TF()


# Error map (only meaningful where M is True)
error_map_w_phi = pred_w_phi - w_phi
mask = M

# Display w_phi estimate
plt.figure(figsize=(6, 5))
plt.imshow(pred_w_phi * M_proc, origin='upper')
plt.colorbar(label=r'$w_\phi$ (rad/px)')
plt.title(r'Estimated $w_\phi$ (rad/px)')
plt.tight_layout()
plt.show()

# Histogram of error in w_phi (rad/px)
histEdge2 = np.linspace(-np.pi/10, np.pi/10, 100)
plt.figure(figsize=(6, 4))
plt.hist(error_map_w_phi[mask].ravel(), bins=histEdge2)
plt.title('Histogram of error in $w_\phi$')
plt.xlabel(r'$w_\phi$ error (rad/px)')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# RMSE criterion
rmse_w_phi = np.sqrt(np.mean(error_map_w_phi[mask] ** 2))
print(f"RMSE(w_phi) = {rmse_w_phi:.4f} rad/px")
assert rmse_w_phi < 0.4, "RMSE condition failed (rmse_w_phi >= 0.4 rad/px)"
print("Assertion passed: RMSE(w_phi) < 0.4 rad/px")
# Out:
# [calcSpatialFreqsFilterbank_ParVer_TF] Warm-up time: 19155.41 ms
# [calcSpatialFreqsFilterbank_ParVer_TF] Run 1/1: 1307.98 ms
# calcSpatialFreqsFilterbank_ParVer_TF: 1 runs -> mean = 1307.98 ms, std = 0.00 ms
# RMSE(w_phi) = 0.3243 rad/px
# Assertion passed: RMSE(w_phi) < 0.4 rad/px

# %%
# %%prun -D out.prof
# profile the function call, the cell magic must be the first line of the cell

(pred_w_phi, pred_theta_or, pred_phi_x, pred_phi_y, M_proc)=calcSpatialFreqsFilterbank_ParVer_TF(g, M)
# Out:
#
# *** Profile stats marshalled to file 'out.prof'.
#          19894 function calls (19282 primitive calls) in 1.506 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       364    1.395    0.004    1.395    0.004 {built-in method tensorflow.python._pywrap_tfe.TFE_Py_FastPathExecute}
#        28    0.045    0.002    0.045    0.002 {built-in method tensorflow.python._pywrap_tfe.TFE_Py_Execute}
#         1    0.007    0.007    0.007    0.007 {built-in method _winapi.CreateProcess}
#       164    0.006    0.000    0.007    0.000 constant_op.py:75(convert_to_eager_tensor)
#   487/243    0.004    0.000    1.152    0.005 dispatch.py:1246(op_dispatch_handler)
#      1080    0.003    0.000    0.003    0.000 {built-in method builtins.getattr}
#         9    0.003    0.000    0.003    0.000 {method 'copy' of 'numpy.ndarray' objects}
#       819    0.002    0.000    0.002    0.000 context.py:1025(executing_eagerly)
#   573/243    0.002    0.000    1.159    0.005 traceback_utils.py:138(error_handler)
#       294    0.002    0.000    0.017    0.000 tensor_conversion_registry.py:164(convert)
#         1    0.001    0.001    1.500    1.500 FPA_TensorFlow.py:943(_calcSpatialFreqsFilterbank_ParVer_TF_core)
#         1    0.001    0.001    0.001    0.001 {method 'tofile' of 'numpy.ndarray' objects}
#         5    0.001    0.000    0.001    0.000 {method 'astype' of 'numpy.ndarray' objects}
#       294    0.001    0.000    0.003    0.000 ops.py:596(__tf_tensor__)
#       636    0.001    0.000    0.003    0.000 context.py:2330(executing_eagerly)
#       447    0.001    0.000    0.001    0.000 ops.py:6078(is_auto_dtype_conversion_enabled)
#   244/225    0.001    0.000    0.392    0.002 weak_tensor_ops.py:140(wrapper)
#       246    0.001    0.000    0.003    0.000 ops.py:5493(name_scope)
#        19    0.001    0.000    0.014    0.001 tensor_getitem_override.py:65(_slice_helper)
#       235    0.001    0.000    0.001    0.000 dtypes.py:264(__eq__)
#      1981    0.001    0.000    0.002    0.000 {built-in method builtins.isinstance}
#        72    0.001    0.000    0.326    0.005 override_binary_operator.py:105(binary_op_wrapper)
#       486    0.001    0.000    0.001    0.000 ops.py:377(dtype)
#       191    0.001    0.000    0.001    0.000 dtypes.py:793(as_dtype)
#       124    0.001    0.000    0.008    0.000 constant_tensor_conversion.py:23(_constant_tensor_conversion_function)
#        51    0.001    0.000    0.100    0.002 math_ops.py:938(cast)
#       232    0.001    0.000    0.001    0.000 dtypes.py:83(_is_ref_dtype)
#        89    0.001    0.000    0.001    0.000 {built-in method tensorflow.python.util._pywrap_utils.Flatten}
#         1    0.001    0.001    1.506    1.506 FPA_TensorFlow.py:773(calcSpatialFreqsFilterbank_ParVer_TF)
#         1    0.001    0.001    1.506    1.506 <string>:1(<module>)
#       573    0.000    0.000    0.003    0.000 traceback_utils.py:32(is_traceback_filtering_enabled)
#       268    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:1053(_handle_fromlist)
#        49    0.000    0.000    0.006    0.000 execute.py:222(args_to_matching_eager)
#         1    0.000    0.000    0.000    0.000 {built-in method io.open}
#       164    0.000    0.000    0.008    0.000 constant_op.py:280(_constant_impl)
#       243    0.000    0.000    0.011    0.000 trace.py:178(wrapped)
#       192    0.000    0.000    0.000    0.000 context.py:1047(device_name)
#         2    0.000    0.000    0.075    0.037 FPA_TensorFlow.py:415(calcFreqFromFilterRespose_TF)
#       243    0.000    0.000    0.011    0.000 ops.py:698(convert_to_tensor)
#     97/80    0.000    0.000    0.456    0.006 weak_tensor_ops.py:86(wrapper)
#        20    0.000    0.000    0.000    0.000 typing.py:1408(_get_protocol_attrs)
#       139    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#        89    0.000    0.000    0.002    0.000 array_ops.py:1282(_should_not_autopack)
#        90    0.000    0.000    0.002    0.000 override_binary_operator.py:46(maybe_promote_tensors)
#         5    0.000    0.000    0.147    0.029 fft_ops.py:648(ifftshift)
#        16    0.000    0.000    0.060    0.004 math_ops.py:1405(_truediv_python3)
#        55    0.000    0.000    0.001    0.000 dtypes.py:194(is_compatible_with)
#        39    0.000    0.000    0.001    0.000 tensor_shape.py:820(__init__)
#        16    0.000    0.000    0.002    0.000 array_ops.py:657(shape)
#       232    0.000    0.000    0.001    0.000 dtypes.py:96(base_dtype)
#         7    0.000    0.000    0.003    0.000 array_ops.py:2883(ones)
#        89    0.000    0.000    0.001    0.000 nest.py:198(flatten)
#       141    0.000    0.000    0.000    0.000 tensor_conversion_registry.py:134(get)
#       164    0.000    0.000    0.007    0.000 constant_op.py:297(_constant_eager_impl)
#       317    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#        40    0.000    0.000    0.001    0.000 ops.py:508(shape)
#        17    0.000    0.000    0.005    0.000 gen_array_ops.py:8670(reshape)
#        25    0.000    0.000    0.227    0.009 tensor_math_operator_overrides.py:61(_mul_dispatch_factory)
#       164    0.000    0.000    0.009    0.000 constant_op.py:177(constant)
#        14    0.000    0.000    0.066    0.005 override_binary_operator.py:144(r_binary_op_wrapper)
#       649    0.000    0.000    0.000    0.000 context.py:2300(context_safe)
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of '_io._IOBase' objects}
#        16    0.000    0.000    0.004    0.000 gen_array_ops.py:8774(reshape_eager_fallback)
#       137    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#       125    0.000    0.000    0.001    0.000 tensor_shape.py:830(<genexpr>)
#       507    0.000    0.000    0.000    0.000 {method '_datatype_enum' of 'tensorflow.python.framework.ops.EagerTensor' objects}
#        89    0.000    0.000    0.004    0.000 array_ops.py:1292(_autopacking_conversion_function)
#        16    0.000    0.000    0.002    0.000 array_ops.py:689(shape_internal)
#        65    0.000    0.000    0.009    0.000 array_ops_stack.py:24(stack)
#         9    0.000    0.000    0.003    0.000 math_ops.py:1940(range)
#       294    0.000    0.000    0.000    0.000 tensor.py:757(__tf_tensor__)
#       192    0.000    0.000    0.000    0.000 context.py:580(ensure_initialized)
#         7    0.000    0.000    0.004    0.001 math_ops.py:693(complex)
#        25    0.000    0.000    0.225    0.009 gen_math_ops.py:6806(mul)
#        89    0.000    0.000    0.001    0.000 nest_util.py:721(_tf_core_flatten)
#        17    0.000    0.000    0.002    0.000 array_ops.py:1197(_autopacking_helper)
#        86    0.000    0.000    0.000    0.000 tensor_shape.py:728(as_dimension)
#         5    0.000    0.000    0.037    0.007 FPA_TensorFlow.py:19(_box_filter_2d)
#        16    0.000    0.000    0.061    0.004 tensor_math_operator_overrides.py:85(_truediv_factory)
#        25    0.000    0.000    0.226    0.009 math_ops.py:1698(_mul_dispatch)
#        16    0.000    0.000    0.003    0.000 math_ops.py:1665(_add_dispatch)
#        20    0.000    0.000    0.092    0.005 tensor_math_operator_overrides.py:79(_subtract_factory)
#        28    0.000    0.000    0.045    0.002 execute.py:28(quick_execute)
#        19    0.000    0.000    0.000    0.000 ops.py:5748(__enter__)
#       203    0.000    0.000    0.000    0.000 array_ops.py:1288(<genexpr>)
#         9    0.000    0.000    0.001    0.000 array_ops.py:913(rank_internal)
#       139    0.000    0.000    0.001    0.000 abc.py:117(__instancecheck__)
#        24    0.000    0.000    0.098    0.004 gen_math_ops.py:2097(cast)
#        89    0.000    0.000    0.001    0.000 nest_util.py:615(flatten)
#        16    0.000    0.000    0.004    0.000 tensor_math_operator_overrides.py:25(_add_dispatch_factory)
#        10    0.000    0.000    0.001    0.000 typing.py:1490(__instancecheck__)
#        86    0.000    0.000    0.000    0.000 tensor_shape.py:204(__init__)
#        20    0.000    0.000    0.091    0.005 gen_math_ops.py:12212(sub)
#        14    0.000    0.000    0.000    0.000 {method '_numpy_internal' of 'tensorflow.python.framework.ops.EagerTensor' objects}
#         7    0.000    0.000    0.107    0.015 gen_math_ops.py:12033(square)
#         6    0.000    0.000    0.003    0.000 gen_math_ops.py:5278(less)
#         1    0.000    0.000    0.006    0.006 math_ops.py:111(linspace_nd)
#        48    0.000    0.000    0.000    0.000 tensor.py:251(__getattr__)
#         2    0.000    0.000    0.149    0.075 math_ops.py:2550(reduce_variance)
#         5    0.000    0.000    0.001    0.000 array_ops.py:596(shape_v2)
#        11    0.000    0.000    0.002    0.000 array_ops.py:2722(array_like_impl)
#         1    0.000    0.000    1.506    1.506 {built-in method builtins.exec}
#         9    0.000    0.000    0.002    0.000 array_ops.py:2766(zeros_like_impl)
#        17    0.000    0.000    0.001    0.000 gen_array_ops.py:2365(expand_dims)
#        38    0.000    0.000    0.000    0.000 context.py:1042(scope_name)
#         1    0.000    0.000    0.000    0.000 subprocess.py:531(list2cmdline)
#       192    0.000    0.000    0.000    0.000 context.py:983(_handle)
#        25    0.000    0.000    0.225    0.009 math_ops.py:475(multiply)
#         5    0.000    0.000    0.078    0.016 math_ops.py:359(abs)
#        23    0.000    0.000    0.004    0.000 gen_array_ops.py:6677(pack)
#        76    0.000    0.000    0.000    0.000 ops.py:560(graph)
#        16    0.000    0.000    0.003    0.000 gen_math_ops.py:459(add_v2)
#         6    0.000    0.000    0.018    0.003 array_ops.py:5122(gather_nd)
#         2    0.000    0.000    0.058    0.029 sort_ops.py:241(_ascending_sort)
#         1    0.000    0.000    0.010    0.010 image_viewer_app.py:320(launch_image_viewer)
#        19    0.000    0.000    0.004    0.000 gen_array_ops.py:10789(strided_slice)
#        10    0.000    0.000    0.020    0.002 gen_math_ops.py:6984(neg)
#       267    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#         5    0.000    0.000    0.031    0.006 nn_ops.py:2367(conv2d)
#         5    0.000    0.000    0.069    0.014 gen_math_ops.py:3819(exp)
#       227    0.000    0.000    0.000    0.000 ops.py:182(__exit__)
#        16    0.000    0.000    0.059    0.004 gen_math_ops.py:8139(real_div)
#        16    0.000    0.000    0.001    0.000 gen_array_ops.py:9560(shape)
#        47    0.000    0.000    0.000    0.000 {method '_shape_tuple' of 'tensorflow.python.framework.ops.EagerTensor' objects}
#         6    0.000    0.000    0.022    0.004 FPA_TensorFlow.py:466(_gather_at)
#       183    0.000    0.000    0.000    0.000 context.py:2293(context)
#       363    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         9    0.000    0.000    0.001    0.000 gen_array_ops.py:3560(fill)
#        90    0.000    0.000    0.000    0.000 ops.py:6085(is_numpy_style_type_promotion)
#        28    0.000    0.000    0.000    0.000 execute.py:271(<listcomp>)
#        20    0.000    0.000    0.003    0.000 api.py:37(call_with_layout)
#         2    0.000    0.000    0.151    0.075 FPA_TensorFlow.py:53(_median_filter_2d)
#         7    0.000    0.000    0.001    0.000 math_ops.py:1628(floordiv)
#       141    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         5    0.000    0.000    0.137    0.027 gen_manip_ops.py:29(roll)
#        17    0.000    0.000    0.005    0.000 array_ops.py:63(reshape)
#        20    0.000    0.000    0.091    0.005 math_ops.py:539(subtract)
#        19    0.000    0.000    0.000    0.000 ops.py:5782(__exit__)
#        19    0.000    0.000    0.005    0.000 array_ops.py:994(strided_slice)
#         4    0.000    0.000    0.002    0.000 gen_math_ops.py:5363(less_eager_fallback)
#         1    0.000    0.000    0.003    0.003 array_ops.py:3344(meshgrid)
#        17    0.000    0.000    0.000    0.000 array_ops.py:1246(_get_dtype_from_nested_lists)
#         3    0.000    0.000    0.043    0.014 gen_array_ops.py:827(broadcast_to)
#         4    0.000    0.000    0.048    0.012 gen_math_ops.py:6484(mean)
#        13    0.000    0.000    0.002    0.000 deprecation.py:554(new_func)
#        53    0.000    0.000    0.000    0.000 dtypes.py:277(__ne__)
#         4    0.000    0.000    0.001    0.000 gen_math_ops.py:10026(select)
#         2    0.000    0.000    0.059    0.029 sort_ops.py:153(_sort_or_argsort)
#        28    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#       227    0.000    0.000    0.000    0.000 ops.py:176(__init__)
#         9    0.000    0.000    0.002    0.000 array_ops.py:204(fill)
#         4    0.000    0.000    0.048    0.012 math_ops.py:2490(reduce_mean)
#        19    0.000    0.000    0.000    0.000 ops.py:5531(<genexpr>)
#        36    0.000    0.000    0.000    0.000 execute.py:328(_is_keras_symbolic_tensor)
#         4    0.000    0.000    0.001    0.000 array_ops.py:4747(gather)
#       227    0.000    0.000    0.000    0.000 ops.py:179(__enter__)
#        11    0.000    0.000    0.003    0.000 gen_math_ops.py:10127(select_v2)
#         3    0.000    0.000    0.001    0.000 gen_math_ops.py:11914(sqrt)
#         7    0.000    0.000    0.001    0.000 array_ops.py:4199(squeeze)
#         6    0.000    0.000    0.018    0.003 gen_array_ops.py:3834(gather_nd)
#         7    0.000    0.000    0.001    0.000 constant_op.py:337(_tensor_shape_tensor_conversion_function)
#        20    0.000    0.000    0.000    0.000 tensor_getitem_override.py:49(_check_index)
#        28    0.000    0.000    0.000    0.000 {built-in method tensorflow.python._pywrap_tfe.TFE_Py_TapeSetIsEmpty}
#         7    0.000    0.000    0.001    0.000 gen_math_ops.py:4057(floor_div)
#        14    0.000    0.000    0.000    0.000 ops.py:371(_numpy)
#         4    0.000    0.000    0.002    0.001 check_ops.py:436(_binary_assert)
#         7    0.000    0.000    0.003    0.000 gen_math_ops.py:2292(_complex)
#         2    0.000    0.000    0.225    0.112 gen_spectral_ops.py:811(ifft2d)
#        86    0.000    0.000    0.000    0.000 tensor_shape.py:270(value)
#         1    0.000    0.000    0.000    0.000 format.py:414(_write_array_header)
#        28    0.000    0.000    0.000    0.000 backprop.py:156(_must_record_gradient)
#        26    0.000    0.000    0.000    0.000 shape_util.py:42(maybe_set_static_shape)
#         9    0.000    0.000    0.001    0.000 gen_array_ops.py:13045(zeros_like)
#         2    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         7    0.000    0.000    0.001    0.000 tensor_math_operator_overrides.py:43(_floordiv_factory)
#        10    0.000    0.000    0.000    0.000 typing.py:1425(_is_callable_members_only)
#         2    0.000    0.000    0.001    0.000 math_ops.py:788(real)
#        12    0.000    0.000    0.001    0.000 tensor_util.py:896(constant_value)
#         2    0.000    0.000    0.150    0.075 math_ops.py:2613(reduce_std)
#         1    0.000    0.000    0.000    0.000 ntpath.py:490(normpath)
#         7    0.000    0.000    0.000    0.000 numeric.py:1855(isscalar)
#         9    0.000    0.000    0.001    0.000 gen_math_ops.py:7988(_range)
#        17    0.000    0.000    0.001    0.000 array_ops.py:391(expand_dims_v2)
#        11    0.000    0.000    0.003    0.000 array_ops.py:4411(where_v2)
#        82    0.000    0.000    0.000    0.000 ops.py:6178(is_symbolic_tensor)
#         4    0.000    0.000    0.001    0.000 gen_math_ops.py:10110(select_eager_fallback)
#        16    0.000    0.000    0.060    0.004 math_ops.py:1454(truediv)
#         1    0.000    0.000    0.007    0.007 subprocess.py:1354(_execute_child)
#         5    0.000    0.000    0.031    0.006 gen_nn_ops.py:1269(conv2d)
#        19    0.000    0.000    0.000    0.000 context.py:1037(scope_name)
#         1    0.000    0.000    0.002    0.002 npyio.py:475(save)
#         1    0.000    0.000    0.000    0.000 {built-in method nt._getfullpathname}
#         4    0.000    0.000    0.001    0.000 math_ops.py:3083(reduce_all)
#         5    0.000    0.000    0.069    0.014 math_ops.py:5459(exp)
#         2    0.000    0.000    0.001    0.000 math_ops.py:829(imag)
#         8    0.000    0.000    0.000    0.000 math_ops.py:2058(_may_reduce_to_scalar)
#        20    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         9    0.000    0.000    0.002    0.000 array_ops.py:2557(wrapped)
#         7    0.000    0.000    0.001    0.000 gen_array_ops.py:10580(squeeze)
#        33    0.000    0.000    0.000    0.000 tensor_shape.py:892(rank)
#         8    0.000    0.000    0.001    0.000 math_ops.py:2035(_ReductionDims)
#         3    0.000    0.000    0.001    0.000 check_ops.py:770(assert_equal)
#        15    0.000    0.000    0.002    0.000 tensor_conversion.py:166(convert_to_tensor_v2)
#         3    0.000    0.000    0.000    0.000 ntpath.py:151(splitdrive)
#         8    0.000    0.000    0.002    0.000 ops.py:383(numpy)
#         2    0.000    0.000    0.059    0.029 sort_ops.py:29(sort)
#        17    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         2    0.000    0.000    0.001    0.001 math_ops.py:863(angle)
#         1    0.000    0.000    0.007    0.007 subprocess.py:758(__init__)
#         2    0.000    0.000    0.039    0.020 sort_ops.py:186(_descending_sort)
#         8    0.000    0.000    0.002    0.000 array_ops.py:2667(zeros_like_v2)
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         5    0.000    0.000    0.000    0.000 {built-in method tensorflow.python.util._pywrap_utils.IsResourceVariable}
#         2    0.000    0.000    0.037    0.019 gen_nn_ops.py:12553(top_kv2)
#         1    0.000    0.000    0.043    0.043 gen_array_ops.py:932(broadcast_to_eager_fallback)
#         2    0.000    0.000    0.004    0.002 tensor_math_operator_overrides.py:73(_pow_factory)
#        19    0.000    0.000    0.000    0.000 ops.py:5730(__init__)
#        19    0.000    0.000    0.000    0.000 ops.py:5772(_restore_name_scope)
#        28    0.000    0.000    0.000    0.000 abc.py:121(__subclasscheck__)
#        13    0.000    0.000    0.000    0.000 context.py:2963(_tmp_in_graph_mode)
#         9    0.000    0.000    0.000    0.000 dtypes.py:110(real_dtype)
#        28    0.000    0.000    0.000    0.000 tensor_shape.py:913(ndims)
#        15    0.000    0.000    0.002    0.000 tensor_conversion.py:96(convert_to_tensor_v2_with_dispatch)
#        45    0.000    0.000    0.000    0.000 array_ops.py:1211(<genexpr>)
#         2    0.000    0.000    0.004    0.002 math_ops.py:663(pow)
#        20    0.000    0.000    0.000    0.000 typing.py:1427(<genexpr>)
#        21    0.000    0.000    0.001    0.000 tensor_util.py:1128(is_tf_type)
#         2    0.000    0.000    0.000    0.000 array_ops.py:800(size)
#         5    0.000    0.000    0.137    0.027 manip_ops.py:27(roll)
#     67/65    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         4    0.000    0.000    0.000    0.000 gen_array_ops.py:4001(gather_v2)
#         1    0.000    0.000    0.000    0.000 {built-in method _warnings.warn}
#         4    0.000    0.000    0.001    0.000 gen_math_ops.py:6381(maximum)
#         9    0.000    0.000    0.001    0.000 array_ops.py:877(rank)
#         4    0.000    0.000    0.001    0.000 tensor_math_operator_overrides.py:148(wrapper)
#        10    0.000    0.000    0.000    0.000 nn_ops.py:221(_get_sequence)
#         2    0.000    0.000    0.000    0.000 array_ops.py:839(size_internal)
#         4    0.000    0.000    0.000    0.000 gen_math_ops.py:520(_all)
#        12    0.000    0.000    0.000    0.000 {built-in method nt.fspath}
#         8    0.000    0.000    0.000    0.000 math_ops.py:2053(_has_fully_defined_shape)
#         3    0.000    0.000    0.077    0.026 gen_math_ops.py:2374(complex_abs)
#         6    0.000    0.000    0.018    0.003 array_ops.py:5381(gather_nd_v2)
#        20    0.000    0.000    0.000    0.000 {method 'keys' of 'mappingproxy' objects}
#         1    0.000    0.000    0.000    0.000 format.py:366(_wrap_header)
#         4    0.000    0.000    0.000    0.000 gen_math_ops.py:3426(equal)
#         1    0.000    0.000    0.001    0.001 format.py:666(write_array)
#        10    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         1    0.000    0.000    0.000    0.000 math_ops.py:908(round)
#        20    0.000    0.000    0.000    0.000 typing.py:1506(<genexpr>)
#         2    0.000    0.000    0.004    0.002 gen_math_ops.py:7333(_pow)
#         2    0.000    0.000    0.001    0.000 gen_array_ops.py:3628(fill_eager_fallback)
#         2    0.000    0.000    0.000    0.000 array_ops.py:2815(ones_like_v2)
#         1    0.000    0.000    0.001    0.001 gen_manip_ops.py:103(roll_eager_fallback)
#         7    0.000    0.000    0.000    0.000 tensor_shape.py:1416(is_fully_defined)
#         1    0.000    0.000    0.002    0.002 gen_spectral_ops.py:440(fft2d)
#        18    0.000    0.000    0.000    0.000 flags.py:25(config)
#         7    0.000    0.000    0.001    0.000 array_ops.py:4254(squeeze_v2)
#         4    0.000    0.000    0.001    0.000 array_ops.py:4330(where)
#         1    0.000    0.000    0.000    0.000 subprocess.py:1227(_close_pipe_fds)
#         1    0.000    0.000    0.000    0.000 ntpath.py:564(abspath)
#         5    0.000    0.000    0.031    0.006 nn_ops.py:2260(conv2d_v2)
#        19    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 __init__.py:420(_make)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:71(_wrapreduction)
#         9    0.000    0.000    0.000    0.000 ops.py:521(get_shape)
#         2    0.000    0.000    0.028    0.014 gen_math_ops.py:821(arg_max)
#         4    0.000    0.000    0.001    0.000 execute.py:267(<listcomp>)
#         2    0.000    0.000    0.000    0.000 gen_math_ops.py:8063(real)
#         5    0.000    0.000    0.000    0.000 nn_ops.py:1941(convert_padding)
#         1    0.000    0.000    0.000    0.000 random.py:519(<listcomp>)
#        16    0.000    0.000    0.000    0.000 math_ops.py:2009(<genexpr>)
#         1    0.000    0.000    0.000    0.000 contextlib.py:533(__exit__)
#         2    0.000    0.000    0.087    0.043 gen_array_ops.py:2458(extract_image_patches)
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         2    0.000    0.000    0.087    0.043 array_ops.py:6136(extract_image_patches_v2)
#         2    0.000    0.000    0.000    0.000 array_ops.py:1316(concat)
#         4    0.000    0.000    0.000    0.000 ops.py:312(__bool__)
#         1    0.000    0.000    0.000    0.000 random.py:506(choices)
#         1    0.000    0.000    0.000    0.000 subprocess.py:1065(__del__)
#         1    0.000    0.000    0.000    0.000 tempfile.py:153(__next__)
#         7    0.000    0.000    0.000    0.000 tensor_shape.py:1430(as_list)
#         2    0.000    0.000    0.002    0.001 gen_math_ops.py:5182(is_nan)
#         2    0.000    0.000    0.028    0.014 math_ops.py:262(argmax_v2)
#        31    0.000    0.000    0.000    0.000 tensor_shape.py:1419(<genexpr>)
#         6    0.000    0.000    0.000    0.000 os.py:817(fsdecode)
#         2    0.000    0.000    0.001    0.001 gen_math_ops.py:596(angle)
#         1    0.000    0.000    0.000    0.000 ntpath.py:104(join)
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.arange}
#         2    0.000    0.000    0.037    0.019 nn_ops.py:5815(top_k)
#         2    0.000    0.000    0.000    0.000 ops.py:309(__index__)
#         2    0.000    0.000    0.000    0.000 gen_math_ops.py:4241(greater)
#         2    0.000    0.000    0.000    0.000 gen_math_ops.py:6637(minimum)
#         3    0.000    0.000    0.000    0.000 math_ops.py:1784(equal)
#         2    0.000    0.000    0.001    0.000 gen_math_ops.py:4795(imag)
#         1    0.000    0.000    0.001    0.001 check_ops.py:987(assert_greater)
#         2    0.000    0.000    0.000    0.000 gen_array_ops.py:1279(concat_v2)
#         1    0.000    0.000    0.001    0.001 array_ops.py:3423(<listcomp>)
#         3    0.000    0.000    0.002    0.001 check_ops.py:762(assert_equal_v2)
#         2    0.000    0.000    0.000    0.000 gen_array_ops.py:6620(ones_like)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:2979(prod)
#         4    0.000    0.000    0.000    0.000 math_ops.py:2010(<listcomp>)
#        14    0.000    0.000    0.000    0.000 deprecation.py:670(deprecated_argument_lookup)
#         2    0.000    0.000    0.000    0.000 gen_math_ops.py:27(_abs)
#        20    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 api.py:326(breakpoint)
#         1    0.000    0.000    0.000    0.000 format.py:338(header_data_from_array_1_0)
#         1    0.000    0.000    0.000    0.000 gen_math_ops.py:168(acos)
#         1    0.000    0.000    0.000    0.000 gen_math_ops.py:1282(atan2)
#         2    0.000    0.000    0.000    0.000 array_ops.py:318(expand_dims)
#         1    0.000    0.000    0.000    0.000 public_api.py:42(wrapper)
#         4    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 format.py:243(dtype_to_descr)
#         2    0.000    0.000    0.000    0.000 dtypes.py:121(as_numpy_dtype)
#         1    0.000    0.000    0.000    0.000 math_ops.py:5420(sqrt)
#         1    0.000    0.000    0.000    0.000 subprocess.py:171(__init__)
#         4    0.000    0.000    0.000    0.000 tensor_shape.py:941(__getitem__)
#         1    0.000    0.000    0.000    0.000 py3k.py:49(isfileobj)
#         2    0.000    0.000    0.000    0.000 {built-in method _winapi.CloseHandle}
#         1    0.000    0.000    0.000    0.000 gen_math_ops.py:8822(round)
#         1    0.000    0.000    0.000    0.000 array_ops.py:6357(convert_to_int_tensor)
#         1    0.000    0.000    0.000    0.000 gen_array_ops.py:9784(_slice)
#         1    0.000    0.000    0.000    0.000 contextlib.py:452(__init__)
#         1    0.000    0.000    0.000    0.000 format.py:201(magic)
#         1    0.000    0.000    0.000    0.000 gen_array_ops.py:697(broadcast_args)
#         2    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x00007FFE36965D50}
#         1    0.000    0.000    0.000    0.000 gen_math_ops.py:4342(greater_equal)
#        20    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 tempfile.py:142(rng)
#         4    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 tempfile.py:313(gettempdir)
#         1    0.000    0.000    0.000    0.000 subprocess.py:1481(_internal_poll)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.repr}
#         1    0.000    0.000    0.000    0.000 utils.py:1151(drop_metadata)
#         1    0.000    0.000    0.000    0.000 array_ops.py:3412(<listcomp>)
#         1    0.000    0.000    0.001    0.001 check_ops.py:978(assert_greater_v2)
#        10    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.sorted}
#         1    0.000    0.000    0.000    0.000 pydevd_constants.py:834(get_global_debugger)
#         1    0.000    0.000    0.000    0.000 array_ops.py:526(broadcast_dynamic_shape)
#         1    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:72(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.breakpoint}
#         1    0.000    0.000    0.000    0.000 pydevd.py:2920(_is_attached)
#         1    0.000    0.000    0.000    0.000 api.py:322(is_client_connected)
#         1    0.000    0.000    0.000    0.000 array_ops.py:938(slice)
#         1    0.000    0.000    0.000    0.000 math_ops.py:5562(acos)
#         1    0.000    0.000    0.000    0.000 force_pydevd.py:61(debugpy_breakpointhook)
#         8    0.000    0.000    0.000    0.000 {built-in method math.floor}
#         1    0.000    0.000    0.000    0.000 {built-in method _winapi.WaitForSingleObject}
#         1    0.000    0.000    0.000    0.000 array_ops.py:2627(zeros_like)
#         1    0.000    0.000    0.000    0.000 api.py:50(ensure_logging)
#         3    0.000    0.000    0.000    0.000 tensor_getitem_override.py:45(_is_undefined_dimension)
#         1    0.000    0.000    0.000    0.000 subprocess.py:196(Close)
#         1    0.000    0.000    0.000    0.000 {built-in method sys.exc_info}
#         1    0.000    0.000    0.000    0.000 subprocess.py:1260(_get_handles)
#         8    0.000    0.000    0.000    0.000 {method 'random' of '_random.Random' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method _struct.pack}
#         2    0.000    0.000    0.000    0.000 tensor_shape.py:918(__len__)
#         1    0.000    0.000    0.000    0.000 log.py:146(write_format)
#         1    0.000    0.000    0.000    0.000 format.py:390(_wrap_header_guess_version)
#         1    0.000    0.000    0.000    0.000 {built-in method _struct.calcsize}
#         1    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         4    0.000    0.000    0.000    0.000 tensor_shape.py:863(_v2_behavior)
#         2    0.000    0.000    0.000    0.000 tensor_shape.py:924(__bool__)
#         1    0.000    0.000    0.000    0.000 format.py:196(_check_version)
#         1    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#         1    0.000    0.000    0.000    0.000 {method 'lstrip' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'fileno' of '_io.BufferedWriter' objects}
#         2    0.000    0.000    0.000    0.000 typing.py:1737(cast)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'write' of '_io.BufferedWriter' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.asanyarray}
#         1    0.000    0.000    0.000    0.000 contextlib.py:530(__enter__)
#         1    0.000    0.000    0.000    0.000 tempfile.py:301(_gettempdir)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:2974(_prod_dispatcher)
#         1    0.000    0.000    0.000    0.000 subprocess.py:237(_cleanup)
#         1    0.000    0.000    0.000    0.000 tempfile.py:229(_get_candidate_names)
#         1    0.000    0.000    0.000    0.000 npyio.py:471(_save_dispatcher)
#         1    0.000    0.000    0.000    0.000 {built-in method sys.audit}
#         2    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}

# %%
# analyze profiler report
CODE_PROFILE_ANALYIS=False
if CODE_PROFILE_ANALYIS:
    import snakeviz
    print(snakeviz.__file__)
    # !snakeviz out.prof

# %% [markdown]
# Generacion de informe
# correr la celda de abajo para generar un informe HTML

# %%
# --- AUTOMATED EXPORT CELL: Generate HTML (no code) for PDF printing ---
# check nbconvert is installed "pip show nbconvert"
import os
from IPython.display import FileLink, Javascript

nb_name = "testCalcSpatialFreqsFilterBank_CPU-GPU.ipynb"
html_name = nb_name.replace(".ipynb", "_REPORT.html")

print("Saving notebook…")
import ipywidgets as widgets
from IPython.display import Javascript

# Save the notebook
display(Javascript("Jupyter.notebook.save_checkpoint();"))

# Export to HTML (no input code)
cmd = f"jupyter nbconvert --to html --no-input --no-prompt {nb_name} --output {html_name}"
print("Running:", cmd)
os.system(cmd)

print("\nHTML report generated:", html_name)
display(FileLink(html_name))

print("\n➡️ Now open the HTML and choose **Print → Save as PDF**.")
# Out:
# Saving notebook…
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[24], line 10
#       7 html_name = nb_name.replace(".ipynb", "_REPORT.html")
#       9 print("Saving notebook…")
# ---> 10 import ipywidgets as widgets
#      11 from IPython.display import Javascript
#      13 # Save the notebook
#
# ModuleNotFoundError: No module named 'ipywidgets'
