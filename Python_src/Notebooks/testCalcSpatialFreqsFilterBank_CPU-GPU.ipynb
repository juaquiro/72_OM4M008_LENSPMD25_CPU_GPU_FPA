# %% [markdown]
# # CPU+GPU Test of `calcSpatialFreqsFilterBank`
#
# This notebook replicates in Python/NumPy the MATLAB test script `testCalcSpatialFreqsFilterBank.m` for the FilterBank local spatial-frequency estimator `calcSpatialFreqsFilterBank`. The core functions are imported from `FPA_Numpy.py` and `FPA_TensorFlow.py` .
# Here we check NumPy-CPU and TensorFlow-GPU implementations

# %%
# ---
# ✅ Colab bootstrap for LensPMD
# How to open in Colab:
# 1) Clone the LensPMD repo into Google Drive.
# 2) In Drive (web), right-click the notebook → “Open with” → “Google Colab”.
# 3) Run this cell to mount Drive, set the working directory, and verify required paths.
# ---

import os
from pathlib import Path

# === Detect Colab =============================================================
try:
    import google.colab  # type: ignore
    IN_COLAB = True
except ImportError:
    IN_COLAB = False

print(f"Running in Colab? {IN_COLAB}")

# === Setup when in Colab ======================================================
if IN_COLAB:
    from google.colab import drive  # type: ignore
    DRIVE_MOUNT_POINT = "/content/drive"
    PROJECT_REL_PATH = "MyDrive/Colab Notebooks/72_OM4M008_LENSPMD25_CPU_GPU_FPA/Python_src"
    REQUIRED_PATH = "/content/drive/MyDrive/Colab Notebooks/72_OM4M008_LENSPMD25_CPU_GPU_FPA/local_data"

    # Mount Google Drive
    drive.mount(DRIVE_MOUNT_POINT, force_remount=True)

    # Set working directory
    project_path = Path(DRIVE_MOUNT_POINT) / PROJECT_REL_PATH
    if not project_path.exists():
        raise FileNotFoundError(f"❌ Project directory not found: {project_path}")

    os.chdir(project_path)
    print("✅ Working Directory:", Path.cwd())

    # Verify required local_data folder exists
    local_data_path = Path(REQUIRED_PATH)
    if not local_data_path.exists():
        raise FileNotFoundError(
            f"❌ Required directory not found: {local_data_path}\n"
            "Please ensure 'local_data' exists in the LensPMD folder in your Drive."
        )

    print("✅ Required folder found:", local_data_path)
    print("📂 Files in Working Directory:", os.listdir())

else:
    print("Not running in Colab — skipping Drive mount and WD setup.")
    print("Current Working Directory:", Path.cwd())
# Out:
# Running in Colab? False
# Not running in Colab — skipping Drive mount and WD setup.
# Current Working Directory: c:\user\AQ_SCC\72_OM4M008_LENSPMD25_CPU_GPU_FPA\Python_src\Notebooks

# %%
"""
Side effects of importing `notebook_bootstrap`:

When this module is imported, it performs the following actions immediately:

1. Determines the directory where this file (`notebook_add_path.py`) resides.
   This directory is assumed to be `Python_src/Notebooks/`.

2. Computes the parent directory of that location, assumed to be the project
   source directory (`Python_src/`).

3. Prepends that project source directory to `sys.path`, if it is not already
   present.

As a result, Jupyter notebooks located inside `Python_src/Notebooks/` can
import project modules under development using standard import statements, e.g.:

    from image_viewer_app import launch_image_viewer

Scope and limitations:
- The modification of `sys.path` is temporary and applies only to the current
  Python interpreter / Jupyter kernel.
- No environment variables (such as PYTHONPATH) are modified.
- No changes persist after the kernel is restarted.
- This module is intended for interactive development and debugging only.

This import should be removed once the project is packaged and installed
properly (e.g. via `pip install -e .`).
"""

import notebook_add_path
# Out:
# [notebook_bootstrap] Added to sys.path: C:\user\AQ_SCC\72_OM4M008_LENSPMD25_CPU_GPU_FPA\Python_src

# %%
import tensorflow as tf

# check for tensor flow and list devices
print("TensorFlow version:", tf.__version__)
print("Built with CUDA:", tf.test.is_built_with_cuda())
print("GPU devices:", tf.config.list_physical_devices('GPU'))
if tf.config.list_physical_devices('GPU'):
    try:
        for d in tf.config.list_physical_devices('GPU'):
            tf.config.experimental.set_memory_growth(d, True)
    except Exception as e:
        print("Could not set memory growth:", e)

print("CPU devices:", tf.config.list_physical_devices('CPU'))
# Out:
# TensorFlow version: 2.19.1
# Built with CUDA: False
# GPU devices: []
# CPU devices: [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %%
"""
Matplotlib backend setup (must run first).

Configures the matplotlib backend for inline rendering.
Must be executed before importing matplotlib.pyplot (directly or indirectly),
otherwise the backend is locked and this setting has no effect.

Imports for the FPA image processing and timining (the partial)
"""
# %matplotlib inline
import matplotlib
matplotlib.use("module://matplotlib_inline.backend_inline")
print(matplotlib.get_backend())

from matplotlib import pyplot as plt
import numpy as np
from FPA_Numpy import calcSpatialFreqsHilbert2D_NumPy, calcSpatialFreqsFilterbank_ParVer_NumPy
from FPA_TensorFlow import calcSpatialFreqsHilbert2D_TF, calcSpatialFreqsFilterbank_ParVer_TF
from FPA_Utils import time_function, peaks_2d

from functools import partial
# Out:
# module://matplotlib_inline.backend_inline

# %%
# Synthetic interferogram (Caso 1: HIFREQ)
NR, NC = 558, 553
y, x = np.meshgrid(
    np.arange(NR, dtype=np.float32),
    np.arange(NC, dtype=np.float32),
    indexing="ij",
)
x = x - 0.5 * NC
y = y - 0.5 * NR

# ROI mask
M = np.ones((NR, NC), dtype=bool)

# Spatial carrier
w0 = np.array([np.pi/4, np.pi/4], dtype=np.float32)  # rad/px
fringe_carrier_or = np.arctan2(w0[1], w0[0])

# Smooth phase term via peaks (already sized NR x NC)
phi_0 = 3.0 * peaks_2d(NR, NC)
phi = phi_0 + w0[0] * x + w0[1] * y

# Ground-truth spatial freqs
phi_y, phi_x = np.gradient(phi.astype(np.float32))  # np.gradient -> (d/dy, d/dx)
w_phi = np.abs(phi_x + 1j * phi_y)
w_phi = w_phi * M  # apply mask
theta_or = np.arctan2(-phi_y, phi_x)

# DC and modulation in gray values
b = np.float32(100.0)
m = np.float32(64.0)
nL_mod = np.float32(0.0)
nL = 100.0 * nL_mod / m  # not used explicitly

# Interferogram in [0, 255]
g_float = b + m * np.cos(phi) + nL_mod * np.random.randn(NR, NC).astype(np.float32)
g_uint8 = np.clip(np.round(g_float), 0, 255).astype(np.uint8)
g = g_uint8.astype(np.float32)
g = g * M.astype(np.float32)

# Ground-truth phasor (for reference)
z = b * np.exp(1j * phi)
print("Synthetic interferogram generated.")

plt.imshow(g, aspect='auto', cmap='gray')
plt.title("Synthetic interferogram")
plt.colorbar()
plt.show()
# Out:
# Synthetic interferogram generated.

# %%
# Time numpy paralell filter bank method (outputs kept if needed)
# use partial to keep funcion metadata
f_calcSpatialFreqsFilterbank_ParVer_NumPy = partial(calcSpatialFreqsFilterbank_ParVer_NumPy, g, M)

# Time  numpy paralell filter bank method and keep outputs for plotting
res_calcSpatialFreqsFilterbank_ParVer_NumPy = time_function(f_calcSpatialFreqsFilterbank_ParVer_NumPy.func.__name__, f_calcSpatialFreqsFilterbank_ParVer_NumPy, n_runs=1, verbose=True)

# calculate spatial freqs
(pred_w_phi, pred_theta_or, pred_phi_x, pred_phi_y, M_proc)=f_calcSpatialFreqsFilterbank_ParVer_NumPy()

# Error map (only meaningful where M is True)
error_map_w_phi = pred_w_phi - w_phi
mask = M

# Display w_phi estimate
plt.figure(figsize=(6, 5))
plt.imshow(pred_w_phi * M_proc, origin='upper')
plt.colorbar(label=r'$w_\phi$ (rad/px)')
plt.title(r'Estimated $w_\phi$ (rad/px)')
plt.tight_layout()
plt.show()

# Histogram of error in w_phi (rad/px)
histEdge2 = np.linspace(-np.pi/10, np.pi/10, 100)
plt.figure(figsize=(6, 4))
plt.hist(error_map_w_phi[mask].ravel(), bins=histEdge2)
plt.title('Histogram of error in $w_\phi$')
plt.xlabel(r'$w_\phi$ error (rad/px)')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# RMSE criterion
rmse_w_phi = np.sqrt(np.mean(error_map_w_phi[mask] ** 2))
print(f"RMSE(w_phi) = {rmse_w_phi:.4f} rad/px")
assert rmse_w_phi < 0.4, "RMSE condition failed (rmse_w_phi >= 0.4 rad/px)"
print("Assertion passed: RMSE(w_phi) < 0.4 rad/px")
# Out:
# [calcSpatialFreqsFilterbank_ParVer_NumPy] Warm-up time: 6734.32 ms
# [calcSpatialFreqsFilterbank_ParVer_NumPy] Run 1/1: 6782.79 ms
# calcSpatialFreqsFilterbank_ParVer_NumPy: 1 runs -> mean = 6782.79 ms, std = 0.00 ms
# RMSE(w_phi) = 0.0082 rad/px
# Assertion passed: RMSE(w_phi) < 0.4 rad/px

# %%
#this is to avoid restrting the kernel while iterating
import importlib
import FPA_TensorFlow

importlib.reload(FPA_TensorFlow)
from FPA_TensorFlow import calcSpatialFreqsFilterbank_ParVer_TF


# Time tensor flow paralell filter bank method (outputs kept if needed)
# use partial to keep funcion metadata
f_calcSpatialFreqsFilterbank_ParVer_TF = partial(calcSpatialFreqsFilterbank_ParVer_TF, g, M, calcMethod = "maxFreq")

# Time tensor flow paralell filter bank method and keep outputs for plotting
res_calcSpatialFreqsFilterbank_ParVer_TF = time_function(f_calcSpatialFreqsFilterbank_ParVer_TF.func.__name__, f_calcSpatialFreqsFilterbank_ParVer_TF, n_runs=1, verbose=True)

# calculate spatial freqs
(pred_w_phi, pred_theta_or, pred_phi_x, pred_phi_y, M_proc)=f_calcSpatialFreqsFilterbank_ParVer_TF()


# Error map (only meaningful where M is True)
error_map_w_phi = pred_w_phi - w_phi
mask = M

# Display w_phi estimate
plt.figure(figsize=(6, 5))
plt.imshow(pred_w_phi * M_proc, origin='upper')
plt.colorbar(label=r'$w_\phi$ (rad/px)')
plt.title(r'Estimated $w_\phi$ (rad/px)')
plt.tight_layout()
plt.show()

# Histogram of error in w_phi (rad/px)
histEdge2 = np.linspace(-np.pi/10, np.pi/10, 100)
plt.figure(figsize=(6, 4))
plt.hist(error_map_w_phi[mask].ravel(), bins=histEdge2)
plt.title('Histogram of error in $w_\phi$')
plt.xlabel(r'$w_\phi$ error (rad/px)')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# RMSE criterion
rmse_w_phi = np.sqrt(np.mean(error_map_w_phi[mask] ** 2))
print(f"RMSE(w_phi) = {rmse_w_phi:.4f} rad/px")
assert rmse_w_phi < 0.4, "RMSE condition failed (rmse_w_phi >= 0.4 rad/px)"
print("Assertion passed: RMSE(w_phi) < 0.4 rad/px")
# Out:
# [calcSpatialFreqsFilterbank_ParVer_TF] Warm-up time: 869.27 ms
# [calcSpatialFreqsFilterbank_ParVer_TF] Run 1/1: 616.33 ms
# calcSpatialFreqsFilterbank_ParVer_TF: 1 runs -> mean = 616.33 ms, std = 0.00 ms
# RMSE(w_phi) = 0.0087 rad/px
# Assertion passed: RMSE(w_phi) < 0.4 rad/px

# %%
# %%prun -D out.prof
# profile the function call, the cell magic must be the first line of the cell

(pred_w_phi, pred_theta_or, pred_phi_x, pred_phi_y, M_proc)=calcSpatialFreqsFilterbank_ParVer_TF(g, M)
# Out:
#
# *** Profile stats marshalled to file 'out.prof'.
#          18720 function calls (18140 primitive calls) in 0.661 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       348    0.607    0.002    0.607    0.002 {built-in method tensorflow.python._pywrap_tfe.TFE_Py_FastPathExecute}
#        24    0.019    0.001    0.019    0.001 {built-in method tensorflow.python._pywrap_tfe.TFE_Py_Execute}
#       154    0.003    0.000    0.004    0.000 constant_op.py:75(convert_to_eager_tensor)
#   471/241    0.003    0.000    0.480    0.002 dispatch.py:1246(op_dispatch_handler)
#         8    0.002    0.000    0.002    0.000 {method 'copy' of 'numpy.ndarray' objects}
#      1022    0.002    0.000    0.002    0.000 {built-in method builtins.getattr}
#       777    0.001    0.000    0.001    0.000 context.py:1170(executing_eagerly)
#         5    0.001    0.000    0.001    0.000 {method 'astype' of 'numpy.ndarray' objects}
#   553/241    0.001    0.000    0.486    0.002 traceback_utils.py:138(error_handler)
#       278    0.001    0.000    0.009    0.000 tensor_conversion_registry.py:164(convert)
#         1    0.001    0.001    0.656    0.656 FPA_TensorFlow.py:942(_calcSpatialFreqsFilterbank_ParVer_TF_core)
#       431    0.001    0.000    0.001    0.000 ops.py:6101(is_auto_dtype_conversion_enabled)
#       278    0.001    0.000    0.001    0.000 ops.py:619(__tf_tensor__)
#       279    0.001    0.000    0.001    0.000 dtypes.py:264(__eq__)
#       604    0.001    0.000    0.002    0.000 context.py:2575(executing_eagerly)
#       234    0.001    0.000    0.001    0.000 ops.py:5516(name_scope)
#        19    0.001    0.000    0.008    0.000 tensor_getitem_override.py:65(_slice_helper)
#        70    0.000    0.000    0.156    0.002 override_binary_operator.py:105(binary_op_wrapper)
#   234/215    0.000    0.000    0.187    0.001 weak_tensor_ops.py:140(wrapper)
#      1935    0.000    0.000    0.001    0.000 {built-in method builtins.isinstance}
#       516    0.000    0.000    0.000    0.000 ops.py:389(dtype)
#        51    0.000    0.000    0.040    0.001 math_ops.py:940(cast)
#       220    0.000    0.000    0.000    0.000 dtypes.py:83(_is_ref_dtype)
#       171    0.000    0.000    0.000    0.000 dtypes.py:830(as_dtype)
#       116    0.000    0.000    0.004    0.000 constant_tensor_conversion.py:23(_constant_tensor_conversion_function)
#         1    0.000    0.000    0.661    0.661 <string>:1(<module>)
#     97/80    0.000    0.000    0.212    0.003 weak_tensor_ops.py:86(wrapper)
#       281    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1053(_handle_fromlist)
#         1    0.000    0.000    0.660    0.660 FPA_TensorFlow.py:772(calcSpatialFreqsFilterbank_ParVer_TF)
#         2    0.000    0.000    0.044    0.022 FPA_TensorFlow.py:414(calcFreqFromFilterRespose_TF)
#       235    0.000    0.000    0.006    0.000 trace.py:178(wrapped)
#        83    0.000    0.000    0.000    0.000 {built-in method tensorflow.python.util._pywrap_utils.Flatten}
#       553    0.000    0.000    0.002    0.000 traceback_utils.py:32(is_traceback_filtering_enabled)
#       154    0.000    0.000    0.004    0.000 constant_op.py:280(_constant_impl)
#        25    0.000    0.000    0.102    0.004 tensor_math_operator_overrides.py:61(_mul_dispatch_factory)
#       278    0.000    0.000    0.000    0.000 tensor.py:757(__tf_tensor__)
#        86    0.000    0.000    0.001    0.000 override_binary_operator.py:46(maybe_promote_tensors)
#       235    0.000    0.000    0.006    0.000 ops.py:721(convert_to_tensor)
#        16    0.000    0.000    0.032    0.002 math_ops.py:1427(_truediv_python3)
#       131    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#        45    0.000    0.000    0.003    0.000 execute.py:222(args_to_matching_eager)
#        37    0.000    0.000    0.000    0.000 tensor_shape.py:820(__init__)
#        14    0.000    0.000    0.001    0.000 array_ops.py:690(shape_internal)
#        16    0.000    0.000    0.000    0.000 typing.py:1408(_get_protocol_attrs)
#        83    0.000    0.000    0.001    0.000 array_ops.py:1315(_should_not_autopack)
#       178    0.000    0.000    0.000    0.000 context.py:1192(device_name)
#       319    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         3    0.000    0.000    0.031    0.010 fft_ops.py:648(ifftshift)
#        38    0.000    0.000    0.001    0.000 ops.py:520(shape)
#        45    0.000    0.000    0.000    0.000 dtypes.py:194(is_compatible_with)
#       133    0.000    0.000    0.000    0.000 tensor_conversion_registry.py:134(get)
#        12    0.000    0.000    0.030    0.003 override_binary_operator.py:144(r_binary_op_wrapper)
#         2    0.000    0.000    0.089    0.045 math_ops.py:2598(reduce_variance)
#        14    0.000    0.000    0.001    0.000 array_ops.py:658(shape)
#       220    0.000    0.000    0.000    0.000 dtypes.py:96(base_dtype)
#        83    0.000    0.000    0.001    0.000 nest.py:198(flatten)
#         7    0.000    0.000    0.002    0.000 array_ops.py:2916(ones)
#       154    0.000    0.000    0.004    0.000 constant_op.py:177(constant)
#         7    0.000    0.000    0.058    0.008 gen_math_ops.py:12033(square)
#         9    0.000    0.000    0.002    0.000 math_ops.py:1983(range)
#       537    0.000    0.000    0.000    0.000 {method '_datatype_enum' of 'tensorflow.python.framework.ops.EagerTensor' objects}
#       154    0.000    0.000    0.004    0.000 constant_op.py:297(_constant_eager_impl)
#       117    0.000    0.000    0.000    0.000 tensor_shape.py:830(<genexpr>)
#        17    0.000    0.000    0.003    0.000 gen_array_ops.py:8711(reshape)
#       127    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#        25    0.000    0.000    0.101    0.004 gen_math_ops.py:6806(mul)
#        20    0.000    0.000    0.045    0.002 tensor_math_operator_overrides.py:91(_subtract_factory)
#         2    0.000    0.000    0.019    0.010 sort_ops.py:241(_ascending_sort)
#        16    0.000    0.000    0.002    0.000 gen_array_ops.py:8815(reshape_eager_fallback)
#        25    0.000    0.000    0.102    0.004 math_ops.py:1741(_mul_dispatch)
#         7    0.000    0.000    0.002    0.000 math_ops.py:695(complex)
#         5    0.000    0.000    0.013    0.003 FPA_TensorFlow.py:18(_box_filter_2d)
#        65    0.000    0.000    0.006    0.000 array_ops_stack.py:24(stack)
#         5    0.000    0.000    0.042    0.008 math_ops.py:361(abs)
#        13    0.000    0.000    0.000    0.000 {method '_numpy_internal' of 'tensorflow.python.framework.ops.EagerTensor' objects}
#        83    0.000    0.000    0.002    0.000 array_ops.py:1325(_autopacking_conversion_function)
#        83    0.000    0.000    0.000    0.000 nest_util.py:721(_tf_core_flatten)
#        11    0.000    0.000    0.002    0.000 array_ops.py:2755(array_like_impl)
#       185    0.000    0.000    0.000    0.000 array_ops.py:1321(<genexpr>)
#        17    0.000    0.000    0.001    0.000 array_ops.py:1198(_autopacking_helper)
#       615    0.000    0.000    0.000    0.000 context.py:2545(context_safe)
#        19    0.000    0.000    0.000    0.000 ops.py:5771(__enter__)
#        25    0.000    0.000    0.101    0.004 math_ops.py:477(multiply)
#        14    0.000    0.000    0.002    0.000 math_ops.py:1708(_add_dispatch)
#       178    0.000    0.000    0.000    0.000 context.py:698(ensure_initialized)
#        16    0.000    0.000    0.032    0.002 tensor_math_operator_overrides.py:97(_truediv_factory)
#        20    0.000    0.000    0.045    0.002 gen_math_ops.py:12212(sub)
#         2    0.000    0.000    0.033    0.016 FPA_TensorFlow.py:52(_median_filter_2d)
#        80    0.000    0.000    0.000    0.000 tensor_shape.py:728(as_dimension)
#       131    0.000    0.000    0.000    0.000 abc.py:117(__instancecheck__)
#         8    0.000    0.000    0.008    0.001 gen_math_ops.py:6984(neg)
#         5    0.000    0.000    0.032    0.006 gen_math_ops.py:3819(exp)
#         8    0.000    0.000    0.000    0.000 typing.py:1490(__instancecheck__)
#         7    0.000    0.000    0.000    0.000 array_ops.py:914(rank_internal)
#        24    0.000    0.000    0.019    0.001 execute.py:28(quick_execute)
#         4    0.000    0.000    0.033    0.008 gen_math_ops.py:6484(mean)
#       215    0.000    0.000    0.000    0.000 ops.py:182(__exit__)
#         9    0.000    0.000    0.001    0.000 array_ops.py:2799(zeros_like_impl)
#        80    0.000    0.000    0.000    0.000 tensor_shape.py:204(__init__)
#        24    0.000    0.000    0.039    0.002 gen_math_ops.py:2097(cast)
#         5    0.000    0.000    0.009    0.002 nn_ops.py:2367(conv2d)
#        83    0.000    0.000    0.000    0.000 nest_util.py:615(flatten)
#         1    0.000    0.000    0.003    0.003 math_ops.py:113(linspace_nd)
#         5    0.000    0.000    0.000    0.000 array_ops.py:597(shape_v2)
#         4    0.000    0.000    0.002    0.001 gen_math_ops.py:5278(less)
#         1    0.000    0.000    0.661    0.661 {built-in method builtins.exec}
#        38    0.000    0.000    0.000    0.000 context.py:1187(scope_name)
#         6    0.000    0.000    0.003    0.001 array_ops.py:5155(gather_nd)
#        38    0.000    0.000    0.000    0.000 tensor.py:251(__getattr__)
#       178    0.000    0.000    0.000    0.000 context.py:1128(_handle)
#         4    0.000    0.000    0.034    0.008 math_ops.py:2538(reduce_mean)
#         3    0.000    0.000    0.001    0.000 gen_math_ops.py:11914(sqrt)
#        20    0.000    0.000    0.003    0.000 api.py:37(call_with_layout)
#        17    0.000    0.000    0.003    0.000 array_ops.py:63(reshape)
#         2    0.000    0.000    0.019    0.010 sort_ops.py:153(_sort_or_argsort)
#        16    0.000    0.000    0.031    0.002 gen_math_ops.py:8139(real_div)
#        14    0.000    0.000    0.002    0.000 tensor_math_operator_overrides.py:25(_add_dispatch_factory)
#        19    0.000    0.000    0.000    0.000 ops.py:5805(__exit__)
#        20    0.000    0.000    0.045    0.002 math_ops.py:541(subtract)
#        45    0.000    0.000    0.000    0.000 {method '_shape_tuple' of 'tensorflow.python.framework.ops.EagerTensor' objects}
#        23    0.000    0.000    0.003    0.000 gen_array_ops.py:6718(pack)
#        19    0.000    0.000    0.003    0.000 gen_array_ops.py:10864(strided_slice)
#        26    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#       133    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         6    0.000    0.000    0.006    0.001 FPA_TensorFlow.py:465(_gather_at)
#       173    0.000    0.000    0.000    0.000 context.py:2538(context)
#        11    0.000    0.000    0.002    0.000 gen_math_ops.py:10127(select_v2)
#         3    0.000    0.000    0.028    0.009 gen_manip_ops.py:29(roll)
#        19    0.000    0.000    0.003    0.000 array_ops.py:995(strided_slice)
#        11    0.000    0.000    0.001    0.000 deprecation.py:554(new_func)
#        17    0.000    0.000    0.001    0.000 gen_array_ops.py:2365(expand_dims)
#       213    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#         7    0.000    0.000    0.001    0.000 array_ops.py:4232(squeeze)
#        17    0.000    0.000    0.000    0.000 array_ops.py:1247(_get_dtype_from_nested_lists)
#         2    0.000    0.000    0.009    0.005 gen_nn_ops.py:12553(top_kv2)
#        86    0.000    0.000    0.000    0.000 ops.py:6108(is_numpy_style_type_promotion)
#         2    0.000    0.000    0.118    0.059 gen_spectral_ops.py:811(ifft2d)
#         4    0.000    0.000    0.001    0.000 check_ops.py:436(_binary_assert)
#         7    0.000    0.000    0.001    0.000 gen_math_ops.py:2292(_complex)
#         9    0.000    0.000    0.001    0.000 array_ops.py:204(fill)
#         9    0.000    0.000    0.001    0.000 array_ops.py:2590(wrapped)
#         2    0.000    0.000    0.090    0.045 math_ops.py:2661(reduce_std)
#       215    0.000    0.000    0.000    0.000 ops.py:176(__init__)
#        60    0.000    0.000    0.000    0.000 ops.py:583(graph)
#        14    0.000    0.000    0.001    0.000 gen_array_ops.py:9635(shape)
#         2    0.000    0.000    0.019    0.010 sort_ops.py:29(sort)
#        20    0.000    0.000    0.000    0.000 tensor_getitem_override.py:49(_check_index)
#         2    0.000    0.000    0.002    0.001 tensor_math_operator_overrides.py:85(_pow_factory)
#         7    0.000    0.000    0.000    0.000 constant_op.py:337(_tensor_shape_tensor_conversion_function)
#        14    0.000    0.000    0.001    0.000 gen_math_ops.py:459(add_v2)
#         5    0.000    0.000    0.032    0.006 math_ops.py:5738(exp)
#         2    0.000    0.000    0.001    0.000 gen_math_ops.py:5363(less_eager_fallback)
#         2    0.000    0.000    0.000    0.000 math_ops.py:831(imag)
#        53    0.000    0.000    0.000    0.000 dtypes.py:277(__ne__)
#         7    0.000    0.000    0.000    0.000 numeric.py:1937(isscalar)
#         2    0.000    0.000    0.011    0.005 sort_ops.py:186(_descending_sort)
#        24    0.000    0.000    0.000    0.000 backprop.py:156(_must_record_gradient)
#         6    0.000    0.000    0.003    0.001 gen_array_ops.py:3854(gather_nd)
#         4    0.000    0.000    0.001    0.000 math_ops.py:3131(reduce_all)
#         9    0.000    0.000    0.001    0.000 gen_array_ops.py:13207(zeros_like)
#         8    0.000    0.000    0.001    0.000 array_ops.py:2700(zeros_like_v2)
#         2    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#        11    0.000    0.000    0.002    0.000 array_ops.py:4444(where_v2)
#         9    0.000    0.000    0.001    0.000 gen_array_ops.py:3580(fill)
#        19    0.000    0.000    0.000    0.000 ops.py:5554(<genexpr>)
#         2    0.000    0.000    0.000    0.000 math_ops.py:790(real)
#       150    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#        26    0.000    0.000    0.000    0.000 shape_util.py:42(maybe_set_static_shape)
#         3    0.000    0.000    0.028    0.009 manip_ops.py:27(roll)
#         8    0.000    0.000    0.001    0.000 math_ops.py:2083(_ReductionDims)
#         3    0.000    0.000    0.018    0.006 gen_array_ops.py:827(broadcast_to)
#         3    0.000    0.000    0.001    0.000 check_ops.py:770(assert_equal)
#         8    0.000    0.000    0.000    0.000 typing.py:1425(_is_callable_members_only)
#        13    0.000    0.000    0.000    0.000 ops.py:383(_numpy)
#        82    0.000    0.000    0.000    0.000 ops.py:6201(is_symbolic_tensor)
#         5    0.000    0.000    0.000    0.000 {built-in method tensorflow.python.util._pywrap_utils.IsResourceVariable}
#         2    0.000    0.000    0.001    0.001 array_ops.py:2848(ones_like_v2)
#         1    0.000    0.000    0.002    0.002 array_ops.py:3377(meshgrid)
#        16    0.000    0.000    0.032    0.002 math_ops.py:1476(truediv)
#        24    0.000    0.000    0.000    0.000 execute.py:271(<listcomp>)
#        24    0.000    0.000    0.000    0.000 {built-in method tensorflow.python._pywrap_tfe.TFE_Py_TapeSetIsEmpty}
#       215    0.000    0.000    0.000    0.000 ops.py:179(__enter__)
#         2    0.000    0.000    0.000    0.000 array_ops.py:4780(gather)
#         2    0.000    0.000    0.000    0.000 __init__.py:420(_make)
#        10    0.000    0.000    0.001    0.000 tensor_util.py:970(constant_value)
#         5    0.000    0.000    0.009    0.002 gen_nn_ops.py:1269(conv2d)
#        29    0.000    0.000    0.000    0.000 tensor_shape.py:892(rank)
#         4    0.000    0.000    0.000    0.000 gen_math_ops.py:6381(maximum)
#         4    0.000    0.000    0.001    0.000 tensor_math_operator_overrides.py:160(wrapper)
#        19    0.000    0.000    0.000    0.000 ops.py:5795(_restore_name_scope)
#         7    0.000    0.000    0.000    0.000 gen_array_ops.py:10655(squeeze)
#         2    0.000    0.000    0.001    0.000 math_ops.py:865(angle)
#        15    0.000    0.000    0.001    0.000 tensor_conversion.py:166(convert_to_tensor_v2)
#        19    0.000    0.000    0.000    0.000 tensor_util.py:1202(is_tf_type)
#         2    0.000    0.000    0.009    0.005 nn_ops.py:5820(top_k)
#         8    0.000    0.000    0.000    0.000 math_ops.py:2101(_has_fully_defined_shape)
#        11    0.000    0.000    0.000    0.000 context.py:3209(_tmp_in_graph_mode)
#         9    0.000    0.000    0.000    0.000 dtypes.py:110(real_dtype)
#        19    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         7    0.000    0.000    0.001    0.000 ops.py:395(numpy)
#         8    0.000    0.000    0.000    0.000 math_ops.py:2106(_may_reduce_to_scalar)
#         9    0.000    0.000    0.000    0.000 gen_math_ops.py:7988(_range)
#        24    0.000    0.000    0.000    0.000 tensor_shape.py:913(ndims)
#         5    0.000    0.000    0.000    0.000 math_ops.py:1671(floordiv)
#        19    0.000    0.000    0.000    0.000 ops.py:5753(__init__)
#        17    0.000    0.000    0.001    0.000 array_ops.py:392(expand_dims_v2)
#        15    0.000    0.000    0.001    0.000 tensor_conversion.py:96(convert_to_tensor_v2_with_dispatch)
#        19    0.000    0.000    0.000    0.000 context.py:1182(scope_name)
#         5    0.000    0.000    0.000    0.000 tensor_math_operator_overrides.py:43(_floordiv_factory)
#        26    0.000    0.000    0.000    0.000 abc.py:121(__subclasscheck__)
#        80    0.000    0.000    0.000    0.000 tensor_shape.py:270(value)
#        28    0.000    0.000    0.000    0.000 execute.py:328(_is_keras_symbolic_tensor)
#        45    0.000    0.000    0.000    0.000 array_ops.py:1212(<genexpr>)
#         1    0.000    0.000    0.001    0.001 gen_spectral_ops.py:440(fft2d)
#         3    0.000    0.000    0.040    0.013 gen_math_ops.py:2374(complex_abs)
#     49/47    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.018    0.018 gen_array_ops.py:932(broadcast_to_eager_fallback)
#         4    0.000    0.000    0.000    0.000 ops.py:320(__bool__)
#        16    0.000    0.000    0.000    0.000 typing.py:1427(<genexpr>)
#        10    0.000    0.000    0.000    0.000 nn_ops.py:221(_get_sequence)
#         2    0.000    0.000    0.002    0.001 math_ops.py:665(pow)
#         6    0.000    0.000    0.003    0.001 array_ops.py:5428(gather_nd_v2)
#         2    0.000    0.000    0.000    0.000 gen_math_ops.py:10026(select)
#        16    0.000    0.000    0.000    0.000 {method 'keys' of 'mappingproxy' objects}
#         2    0.000    0.000    0.000    0.000 gen_array_ops.py:4039(gather_v2)
#         2    0.000    0.000    0.000    0.000 gen_math_ops.py:4795(imag)
#        16    0.000    0.000    0.000    0.000 typing.py:1506(<genexpr>)
#         2    0.000    0.000    0.000    0.000 array_ops.py:801(size)
#         5    0.000    0.000    0.010    0.002 nn_ops.py:2260(conv2d_v2)
#         4    0.000    0.000    0.000    0.000 gen_math_ops.py:520(_all)
#         2    0.000    0.000    0.000    0.000 gen_math_ops.py:10110(select_eager_fallback)
#         2    0.000    0.000    0.018    0.009 gen_math_ops.py:821(arg_max)
#         7    0.000    0.000    0.000    0.000 array_ops.py:878(rank)
#         2    0.000    0.000    0.010    0.005 array_ops.py:6195(extract_image_patches_v2)
#         7    0.000    0.000    0.000    0.000 tensor_shape.py:1417(is_fully_defined)
#         2    0.000    0.000    0.000    0.000 array_ops.py:840(size_internal)
#         2    0.000    0.000    0.000    0.000 gen_array_ops.py:3648(fill_eager_fallback)
#        16    0.000    0.000    0.000    0.000 math_ops.py:2057(<genexpr>)
#         5    0.000    0.000    0.000    0.000 gen_math_ops.py:4057(floor_div)
#         1    0.000    0.000    0.000    0.000 gen_manip_ops.py:103(roll_eager_fallback)
#         2    0.000    0.000    0.002    0.001 gen_math_ops.py:7333(_pow)
#         1    0.000    0.000    0.000    0.000 check_ops.py:987(assert_greater)
#         4    0.000    0.000    0.000    0.000 gen_math_ops.py:3426(equal)
#         2    0.000    0.000    0.010    0.005 gen_array_ops.py:2458(extract_image_patches)
#         2    0.000    0.000    0.018    0.009 math_ops.py:264(argmax_v2)
#         7    0.000    0.000    0.000    0.000 tensor_shape.py:1431(as_list)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:69(_wrapreduction)
#         7    0.000    0.000    0.001    0.000 array_ops.py:4287(squeeze_v2)
#        19    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#        16    0.000    0.000    0.000    0.000 flags.py:25(config)
#         8    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         2    0.000    0.000    0.000    0.000 array_ops.py:4363(where)
#         5    0.000    0.000    0.000    0.000 nn_ops.py:1941(convert_padding)
#        31    0.000    0.000    0.000    0.000 tensor_shape.py:1420(<genexpr>)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         2    0.000    0.000    0.000    0.000 gen_math_ops.py:8063(real)
#         2    0.000    0.000    0.001    0.001 gen_array_ops.py:6661(ones_like)
#         1    0.000    0.000    0.000    0.000 math_ops.py:910(round)
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.arange}
#         2    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x00007FF89AB85D50}
#         2    0.000    0.000    0.002    0.001 gen_math_ops.py:6637(minimum)
#         1    0.000    0.000    0.000    0.000 gen_math_ops.py:8822(round)
#        14    0.000    0.000    0.000    0.000 deprecation.py:670(deprecated_argument_lookup)
#         2    0.000    0.000    0.001    0.001 gen_math_ops.py:27(_abs)
#         2    0.000    0.000    0.000    0.000 gen_math_ops.py:4241(greater)
#         3    0.000    0.000    0.001    0.000 check_ops.py:762(assert_equal_v2)
#         7    0.000    0.000    0.000    0.000 ops.py:533(get_shape)
#         2    0.000    0.000    0.000    0.000 gen_math_ops.py:5182(is_nan)
#         3    0.000    0.000    0.000    0.000 math_ops.py:1827(equal)
#         2    0.000    0.000    0.001    0.000 gen_math_ops.py:596(angle)
#         1    0.000    0.000    0.000    0.000 array_ops.py:2660(zeros_like)
#         1    0.000    0.000    0.001    0.001 array_ops.py:3456(<listcomp>)
#         4    0.000    0.000    0.000    0.000 tensor_shape.py:941(__getitem__)
#         1    0.000    0.000    0.000    0.000 public_api.py:42(wrapper)
#         2    0.000    0.000    0.000    0.000 array_ops.py:1349(concat)
#         4    0.000    0.000    0.000    0.000 math_ops.py:2058(<listcomp>)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:3369(prod)
#         1    0.000    0.000    0.000    0.000 api.py:326(breakpoint)
#        16    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 gen_math_ops.py:1282(atan2)
#         2    0.000    0.000    0.000    0.000 ops.py:317(__index__)
#         2    0.000    0.000    0.000    0.000 execute.py:267(<listcomp>)
#         2    0.000    0.000    0.000    0.000 array_ops.py:318(expand_dims)
#         1    0.000    0.000    0.000    0.000 array_ops.py:6416(convert_to_int_tensor)
#         2    0.000    0.000    0.000    0.000 gen_array_ops.py:1279(concat_v2)
#         1    0.000    0.000    0.000    0.000 math_ops.py:5699(sqrt)
#         1    0.000    0.000    0.000    0.000 force_pydevd.py:61(debugpy_breakpointhook)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.breakpoint}
#        16    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 gen_math_ops.py:168(acos)
#         2    0.000    0.000    0.000    0.000 dtypes.py:121(as_numpy_dtype)
#         3    0.000    0.000    0.000    0.000 tensor_getitem_override.py:45(_is_undefined_dimension)
#         1    0.000    0.000    0.000    0.000 api.py:322(is_client_connected)
#         1    0.000    0.000    0.000    0.000 gen_array_ops.py:9859(_slice)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:70(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 array_ops.py:527(broadcast_dynamic_shape)
#         1    0.000    0.000    0.000    0.000 gen_math_ops.py:4342(greater_equal)
#         1    0.000    0.000    0.000    0.000 check_ops.py:978(assert_greater_v2)
#         1    0.000    0.000    0.000    0.000 math_ops.py:5841(acos)
#         1    0.000    0.000    0.000    0.000 pydevd.py:2920(_is_attached)
#         1    0.000    0.000    0.000    0.000 log.py:146(write_format)
#         1    0.000    0.000    0.000    0.000 gen_array_ops.py:697(broadcast_args)
#         1    0.000    0.000    0.000    0.000 pydevd_constants.py:834(get_global_debugger)
#         1    0.000    0.000    0.000    0.000 api.py:50(ensure_logging)
#         2    0.000    0.000    0.000    0.000 tensor_shape.py:924(__bool__)
#         1    0.000    0.000    0.000    0.000 array_ops.py:3445(<listcomp>)
#         2    0.000    0.000    0.000    0.000 tensor_shape.py:918(__len__)
#         1    0.000    0.000    0.000    0.000 array_ops.py:939(slice)
#         8    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         4    0.000    0.000    0.000    0.000 tensor_shape.py:863(_v2_behavior)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:3364(_prod_dispatcher)
#         2    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 typing.py:1737(cast)
#         2    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}

# %%
# analyze profiler report
CODE_PROFILE_ANALYIS=False
if CODE_PROFILE_ANALYIS:
    import snakeviz
    print(snakeviz.__file__)
    # !snakeviz out.prof

# %% [markdown]
# Generacion de informe
# correr la celda de abajo para generar un informe HTML

# %%
# --- AUTOMATED EXPORT CELL: Generate HTML (no code) for PDF printing ---
# check nbconvert is installed "pip show nbconvert"
import os
from IPython.display import FileLink, Javascript

nb_name = "testCalcSpatialFreqsFilterBank_CPU-GPU.ipynb"
html_name = nb_name.replace(".ipynb", "_REPORT.html")

print("Saving notebook…")
import ipywidgets as widgets
from IPython.display import Javascript

# Save the notebook
display(Javascript("Jupyter.notebook.save_checkpoint();"))

# Export to HTML (no input code)
cmd = f"jupyter nbconvert --to html --no-input --no-prompt {nb_name} --output {html_name}"
print("Running:", cmd)
os.system(cmd)

print("\nHTML report generated:", html_name)
display(FileLink(html_name))

print("\n➡️ Now open the HTML and choose **Print → Save as PDF**.")
# Out:
# Saving notebook…
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 10
#       7 html_name = nb_name.replace(".ipynb", "_REPORT.html")
#       9 print("Saving notebook…")
# ---> 10 import ipywidgets as widgets
#      11 from IPython.display import Javascript
#      13 # Save the notebook
#
# ModuleNotFoundError: No module named 'ipywidgets'
